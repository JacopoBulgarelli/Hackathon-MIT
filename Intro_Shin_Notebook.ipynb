# %% [markdown]
# # Here there will be the description of the Model

# %% [markdown]
# ### The one below is the Excel containing the information regarding the various parameters
#
# ## ALL THIS INFORMATION SHOULD BE UNPACKED AND PRESENTED HERE IN A BETTER FORM

# %%
import pandas as pd

# %%
xls = pd.ExcelFile('Data_Dictionary.xlsx')

df1 = pd.read_excel(xls, 'Travel Data')
df1.drop(0, inplace=True)
df1.rename(columns = {'Data Dictionary - Travel Data': 'Column Name','Unnamed: 1': 'Column Description', 'Unnamed: 2': 'Column Value Examples'}, inplace = True)

df2 = pd.read_excel(xls, 'Survey Data')
df2.drop(0, inplace=True)
df2.rename(columns = {'Data Dictionary - Survey Data': 'Column Name','Unnamed: 1': 'Column Description', 'Unnamed: 2': 'Column Value Examples'}, inplace = True)

# %%
df1
# Out:
#                Column Name                              Column Description  \
# 1                       ID                  The unique ID of the passenger
# 2                   Gender                     The gender of the passenger
# 3            Customer_Type                   Loyalty type of the passenger
# 4                      Age                        The age of the passenger
# 5              Type_Travel             Purpose of travel for the passenger
# 6             Travel_Class  The train class that the passenger traveled in
# 7         Travel_Distance           The distance traveled by the passenger
# 8  Departure_Delay_in_Mins       The delay (in minutes) in train departure
# 9    Arrival_Delay_in_Mins         The delay (in minutes) in train arrival
#
#                              Column Value Examples
# 1  Continuous values like 98800001, 98800002, etc.
# 2                                     Male\nFemale
# 3                Loyal Customer\nDisloyal Customer
# ...

# %%
df2
# Out:
#                                           Column Name  \
# 1                                                  ID
# 2                                   Platform_Location
# 3                                          Seat_Class
# 4                                  Overall_Experience
# 5                                        Seat_Comfort
# 6                             Arrival_Time_Convenient
# 7                                            Catering
# 8                                Onboard_Wifi_Service
# 9                               Onboard_Entertainment
# 10                                     Online_Support
# 11                             Ease_of_Online_Booking
# 12                                    Onboard_Service
# 13                                            Legroom
# 14                                   Baggage_Handling
# 15                                    CheckIn_Service
# 16                                        Cleanliness
# ...
